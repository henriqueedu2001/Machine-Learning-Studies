# %% [markdown]
# Regressão Linear

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
#leitura do dataset
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# vamos selecionar duas features que parecem ter uma correlação linear
X = df['PetalLengthCm']
y = df['PetalWidthCm']

# exibe plot scatter das duas features
plt.title("PetalLength (Cm) vs PetalWidth (Cm)")
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")

plt.scatter(X, y)
plt.show()

# %%
# divide o dataset em 75% para treino e 25% para teste 
train_fraction = 0.75
X_train, x_test, Y_train, y_test = train_test_split(X, y, train_size=train_fraction)

# %%
# exibição do dataset após divisão
plt.scatter(X_train, Y_train, label='treino', c='blue')
plt.scatter(x_test, y_test, label='teste', c='red')

plt.title("Divisão 75% Treino e 25% Teste")
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.legend()
plt.show()

# %%
# treinamento do regressor
linear_regressor = LinearRegression()
linear_regressor.fit(X_train.values.reshape(-1, 1), Y_train)
# Out:
# LinearRegression()

# %%
# coeficientes obtidos pelo regressor
print('coeficiente linear: ', linear_regressor.intercept_)
print('coeficiente angular: ', linear_regressor.coef_[0])
# Out:
# coeficiente linear:  -0.39092526142805273
# coeficiente angular:  0.424403359059793

# %%
# visualização da regressão
predictionLine = linear_regressor.predict(np.arange(0, 10).reshape(-1, 1))

plt.scatter(X_train, Y_train, label='treino', c='blue')
plt.scatter(x_test, y_test, label='teste', c='red')
plt.plot(predictionLine, label='regressão', c='purple')

plt.title("Regressão linear sobre as features petallenght e PetalWidth")
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.legend()
plt.show()

# %%
# cálculo das pontuções para os datasets de treino e de teste
train_score = linear_regressor.score(X_train, Y_train)
test_score = linear_regressor.score(x_test.values.reshape(-1, 1), y_test)

print('pontuação sobre dataset de treino', train_score)
print('pontuação sobre dataset de teste', test_score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 2
#       1 # cálculo das pontuções para os datasets de treino e de teste
# ----> 2 train_score = linear_regressor.score(X_train, Y_train)
#       3 test_score = linear_regressor.score(x_test.values.reshape(-1, 1), y_test)
#       5 print('pontuação sobre dataset de treino', train_score)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:722, in RegressorMixin.score(self, X, y, sample_weight)
#     680 """Return the coefficient of determination of the prediction.
#     681
#     682 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     717 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     718 """
#     720 from .metrics import r2_score
# --> 722 y_pred = self.predict(X)
#     723 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# ...

# %%
petal_lengths = np.array([3, 5, 6])
petal_widths = linear_regressor.predict(petal_lengths.reshape(-1, 1))
print(petal_lengths)
print(petal_widths)
# Out:
# [3 5 6]
# [0.88274335 1.71558162 2.13200075]

# %%
# predição

plt.scatter(X_train, Y_train, label='treino', c='blue')
plt.scatter(x_test, y_test, label='teste', c='red')
plt.scatter(petal_lengths, petal_widths, label='predição', c='green')

plt.title("Predição")
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.legend()
plt.show()
